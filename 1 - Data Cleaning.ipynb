# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('claims_sample_data.csv')
df.head(5)
# Out:
#     MONTH SERVICE_CATEGORY CLAIM_SPECIALTY    PAYER  PAID_AMOUNT
# 0  201801     AncillaryFFS             NaN  Payer F         4281
# 1  201801     AncillaryFFS             NaN  Payer H         2221
# 2  201801     AncillaryFFS             NaN  Payer O         3937
# 3  201801     AncillaryFFS             NaN  Payer W          268
# 4  201801     AncillaryFFS             ACH  Payer W          151

# %% [markdown]
# # General info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52152 entries, 0 to 52151
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MONTH             52152 non-null  int64
#  1   SERVICE_CATEGORY  52152 non-null  object
#  2   CLAIM_SPECIALTY   51901 non-null  object
#  3   PAYER             52152 non-null  object
#  4   PAID_AMOUNT       52152 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 2.0+ MB

# %% [markdown]
# It seems that CLAIM_SPECIALTY has null values

# %%
df.describe()
# Out:
#                MONTH   PAID_AMOUNT
# count   52152.000000  5.215200e+04
# mean   201885.029567  3.708707e+03
# std        72.867005  3.449842e+04
# min    201801.000000 -4.223000e+04
# 25%    201808.000000  1.940000e+02
# 50%    201903.000000  5.860000e+02
# 75%    201911.000000  1.465000e+03
# max    202007.000000  2.268611e+06

# %% [markdown]
# # Check Duplicates

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 5)

# %%
duplicate_rows_df.head(5)
# Out:
# Empty DataFrame
# Columns: [MONTH, SERVICE_CATEGORY, CLAIM_SPECIALTY, PAYER, PAID_AMOUNT]
# Index: []

# %% [markdown]
# # Check NULLs

# %%
print(df.isnull().sum())
# Out:
# MONTH                 0
# SERVICE_CATEGORY      0
# CLAIM_SPECIALTY     251
# PAYER                 0
# PAID_AMOUNT           0
# dtype: int64

# %% [markdown]
# We have null claim specialties

# %% [markdown]
# ## Fill nas

# %%
df = df.fillna('null_specialty')

# %%
print("Unique Claim Specialty: ", len(df['CLAIM_SPECIALTY'].unique()))
# Out:
# Unique Claim Specialty:  906

# %% [markdown]
# # Check values

# %%
df['SERVICE_CATEGORY'].unique()
# Out:
# array(['AncillaryFFS', 'ASCServices', 'ERServices', 'InpatientServices',
#        'OutpatientServices', 'PCPEncounter', 'PCPFFS', 'SNFServices',
#        'SpecialistFFS', 'SpecialistsFFS'], dtype=object)

# %%
print("Unique Service Category: ", len(df['SERVICE_CATEGORY'].unique()))
# Out:
# Unique Service Category:  10

# %%
df['PAYER'].unique()
# Out:
# array(['Payer F', 'Payer H', 'Payer O', 'Payer W', 'Payer UN', 'Payer CA',
#        'Payer CO', 'Payer S', 'Payer B', 'Payer UL'], dtype=object)

# %%
print("Unique Payers number: ", len(df['PAYER'].unique()))
# Out:
# Unique Payers number:  10

# %%
df['MONTH'].unique()
# Out:
# array([201801, 201802, 201803, 201804, 201805, 201806, 201807, 201808,
#        201809, 201810, 201811, 201812, 201900, 201901, 201902, 201903,
#        201904, 201905, 201906, 201907, 201908, 201909, 201910, 201911,
#        201912, 202001, 202002, 202003, 202004, 202005, 202006, 202007])

# %%
print("Unique Months: ", len(df['MONTH'].unique()))
# Out:
# Unique Months:  32

# %%
sorted(df['CLAIM_SPECIALTY'].unique())
# Out:
# ['ABULATORY SURGICAL CENTER',
#  'ACCUP',
#  'ACH',
#  'ACUPU',
#  'ACUPUNCTURIST',
#  'ACUTE CARE HOSPITAL',
#  'ACUTE SHORT TERM HOSPITAL',
#  'ADDMED',
#  'ADDPSY',
#  'ADLMED',
#  'ADVANCED HEART FAILURE AND TRANSPLANT CARDIOLOGY',
#  'ADVANCED REGISTERED NURSE PRACTITIONER',
#  'ADVANCED RN PRACT',
#  'AHFTC',
#  'ALLERGY & IMMUNOLOGY',
#  'ALLERGY / IMMUNOLOGY',
#  'ALLERGY/IMMUNOLOGY',
#  'AMBULANCE',
#  'AMBULANCE SERVICE',
#  'AMBULATORY SURGERY CENTER',
#  'AMBULATORY SURGICAL CENTER',
#  'AMBULATORY SURGICAL FACILITY',
#  'ANALYTICAL LABS',
#  'ANAST',
#  'ANATOM',
#  'ANATOMIC AND CLINICAL PATHOLOGY',
#  'ANATOMIC PATHOLOGY',
#  'ANES ASSIST',
#  'ANESTHESIA',
#  'ANESTHESIOLOGIST',
#  'ANESTHESIOLOGY',
#  'APRN',
#  'ARNP',
#  'ASC',
#  'AUDIO',
#  'AUDIOLOGIST',
#  'AUDIOLOGY',
#  'AUDIOMETRY',
#  'Adolescent Medicine',
#  'Advanced Registered Nurse Prac',
#  'Agencies',
#  'Allergy',
#  'Allergy / Immunology',
#  'Allergy/Immunology',
#  'Ambulance',
#  'Ambulance - Emergency Land',
#  'Ambulance - Land',
#  'Ambulance Service Provider',
#  'Ambulatory Health Care',
#  'Ambulatory Surgery Center',
#  'Ambulatory Surgical Center',
#  'Ambulatory Surgical Centers',
#  'Ambulatory Transportation Services',
#  'Anatomic Path & Clinical Path',
#  'Anatomic Pathology',
#  'Anesthesia/TEE',
#  'Anesthesiologist Assistant\t',
#  'Anesthesiology',
#  'Anesthesiology - Pain Medicine\t',
#  'Anesthetist, Nurse',
#  'Audiologist',
#  'Audiology',
#  'BARIAS',
#  'BARIATRIC SURGERY',
#  'BEHAVIORAL HEALTH COUNSELING',
#  'BEHAVIORAL HEALTH FACILITY',
#  'BEHAVIORAL HEALTH UNIT',
#  'BH',
#  'BLOOD BANK TRANSFU',
#  'Blood Banking/Transfusion Med',
#  'CARD ELECTROPHYSIOLO',
#  'CARDE',
#  'CARDIAC ELECTROPHYSIOLOGY',
#  'CARDIAC MONITORING',
#  'CARDIOLOGY',
#  'CARDIOLOGY/CARDIOVASCULAR DISEASE',
#  'CARDIOTHORACIC SURGE',
#  'CARDIOTHORACIC SURGERY',
#  'CARDIOVASCULAR SURGERY',
#  'CARDMO',
#  'CARE MANAGER',
#  'CARECN',
#  'CARV',
#  'CCS',
#  'CERT CLINIC NURSE',
#  'CERT FIRST ASSISTANT',
#  'CERTIFIED NURSE ANESTHETIST',
#  'CERTIFIED REGISTERED NURSE ANESTHETIST',
#  'CHADP',
#  'CHIROPRACTIC',
#  'CHIROPRACTOR',
#  'CLADC',
#  'CLIN',
#  'CLINIC',
#  'CLINIC CENTER',
#  'CLINICAL GENETICS',
#  'CLINICAL LABORATORY',
#  'CLINICAL NEUROPSYCHOLOGIST',
#  'CLINICAL SOCIAL WORK',
#  'CLINICAL SOCIAL WORKER',
#  'CLINLB',
#  'CLMIS',
#  'CLNEU',
#  'CNA',
#  'COLON / RECTAL SURGERY',
#  'COLON AND RECTAL SURGERY',
#  'COLORECTAL SURGERY',
#  'COMMUNITY HEALTH CENTER',
#  'COMMUNITY MENTAL HEALTH CENTER',
#  'COMMUNITY MENTAL HEALTH CENTER/OTHER REHAB CENTER',
#  'CONFIG - AMR',
#  'CONFIG - CLIA Certification',
#  'CONV CARE CLINIC',
#  'COVERING PHYSICIAN',
#  'CRITICAL ACCESS',
#  'CRITICAL CARE',
#  'CRITICAL CARE PHYSICIAN',
#  'CSW',
#  'CTC',
#  'CVS',
#  'CYTOPA',
#  'Cardiac Electrophysiology',
#  'Cardiology',
#  'Cardiology/Cardiovascular Disease',
#  'Cardiovascular Disease',
#  'Cardiovascular Medicine',
#  'Certified Clinical Nurse Specialist',
#  'Certified Nurse Practitioner',
#  'Certified Registered Nurse Anesthetist (CRNA)',
#  'Certified Registered Nurse First Assistant',
#  'Chiropractic',
#  'Chiropractic Medicine',
#  'Chiropractor - General',
#  'Clinic or Group Practice',
#  'Clinical Cardiac Electrophys',
#  'Clinical Laboratory',
#  'Clinical Medical Laboratory\t',
#  'Clinical Nurse Specialist',
#  'Clinical Nurse Specialist - Adult Health\t',
#  'Clinical Nurse Specialist - BH',
#  'Clinical Pathology',
#  'Colon & Rectal Surgery',
#  'Colon and Rectal Surgery',
#  'Colon/Rectal Surgery',
#  'Critical Care',
#  'Critical Care Medicine',
#  'Critical/Intensive Care Med',
#  'DEFAULT',
#  'DENTAL',
#  'DENTAL GENERAL',
#  'DENTAL ORAL SURGERY',
#  'DENTAL SURGEON',
#  'DENTIST',
#  'DENTISTRY',
#  'DERMATOLOGY',
#  'DERMATOLOGY SURGERY',
#  'DERMATOPATHOLOGY',
#  'DIABETES EDUCATOR',
#  'DIAG X-RAY CLINIC',
#  'DIAGNOSTIC IMAGING',
#  'DIAGNOSTIC RADIOLOGY',
#  'DIAL',
#  'DIALYSIS',
#  'DIALYSIS CENTER',
#  'DIET',
#  'DIETICIAN',
#  'DIETITIAN, REGISTERED',
#  'DISEASE MANAGEMENT',
#  'DME & Medical Supplies, Oxygen Equip & Supplies',
#  'DME & Supplies',
#  'DPUR',
#  'DURABLE MED EQT&MED SUPPL/CARDIOLOGIST',
#  'DURABLE MED EQUIPMENT',
#  'DURABLE MEDICAL EQUIPMENT',
#  'Dental-Oral Maxillofacial Surg',
#  'Dentist, MD',
#  'Dermatology',
#  'Dermatology - Pathology\t',
#  'Dermatopathology',
#  'Diabetes Educator',
#  'Diagnostic Cardiac Monitoring',
#  'Diagnostic Center',
#  'Diagnostic Radiology',
#  'Diagnostic Treatment Center',
#  'Diagnostics',
#  'Diagnostics (Mobile)',
#  'Diagnostics(Sleep Studies Lab)',
#  'Dialysis',
#  'Dialysis/Renal Care-Medicare',
#  'Dietician - Registered\t',
#  'Doctor of Psychology',
#  'Durable Medical Equipment',
#  'Durable Medical Supply',
#  'EMERGENCY MEDICINE',
#  'EMERGENCY MEDICINE, GEN PRACTICE',
#  'EMERGENCY MEDICINE, GENERAL PRACTICE',
#  'EMERGENCY PHYSICIAN',
#  'EMERGENCY ROOM',
#  'ENDOCRINOLOGY',
#  'ENT',
#  'ERROR',
#  'Early Childhood Intervention',
#  'Educational',
#  'ElectroPhysiologic Study',
#  'Emergency Medicine',
#  'Emergency Medicine - Emergency Medical Services\t',
#  'Emergency Medicine - Medical Toxicology\t',
#  'Emergency Medicine, General Practice',
#  'Emergency Response Systems',
#  'End-Stage Renal Disease (ESRD) Treatment\t',
#  'Endocrinology',
#  'Endocrinology, Diab/Metabolism',
#  'Endocrinology, Internal Medicine',
#  'Ent/Otolaryngology',
#  'FACIAL PLASTIC SURGERY',
#  'FAMILY NURSE PRACTIONER',
#  'FAMILY PRACTICE',
#  'FEMPEL',
#  'FIPAL',
#  'FPMRS',
#  'FQHC',
#  'Family Medicine',
#  'Family Medicine - Adult Medicine\t',
#  'Family Practice',
#  'Family Practice Nurse Prac',
#  'Fitness',
#  'GASTHP',
#  'GASTROENTEROLOGY',
#  'GENCOU',
#  'GENERAL PRACTICE',
#  'GENERAL SPECIALIST',
#  'GENERAL SURGERY',
#  'GENET',
#  'GENETICS',
#  'GERI',
#  'GERIATRICS',
#  'GERPSY',
#  'GROUP OF PROVIDERS',
#  'GYM',
#  'GYNE',
#  'GYNECOLOGIC ONCOLOGY',
#  'GYNECOLOGY',
#  'GYNECOLOGY -IN',
#  'Gastroenterology',
#  'General Acute Care Hospital\t',
#  'General Clinic',
#  'General Practice',
#  'General Surgery',
#  'Genetics',
#  'Geriatric Medicine',
#  'Geriatric Medicine Nurse Prac',
#  'Geriatrics',
#  'Gynecologic Oncology',
#  'Gynecological Oncology',
#  'Gynecology',
#  'Gynecology - No Obstetrics',
#  'Gynecology Nurse Practitioner',
#  'HAND SURGERY',
#  'HAPC',
#  'HDM',
#  'HDNCK',
#  'HEAD/NECK SURGERY',
#  'HEADACHE PAIN MANAGEMENT',
#  'HEALTH CARE PROFESSIONALS-OTHER',
#  'HEARING AID CENTER',
#  'HEARING SERVICES',
#  'HEMATOLOGY',
#  'HEMATOLOGY/ONCOLOGY',
#  'HEMP',
#  'HEP',
#  'HEPATITIS',
#  'HEPATOLOGY',
#  'HHA',
#  'HINF',
#  'HMO',
#  'HOME HEALTH',
#  'HOME HEALTH AGENCY',
#  'HOME HEALTH CARE',
#  'HOME HEALTH CARE AGENCY',
#  'HOME HEALTH CENTER',
#  'HOME INFUSION',
#  'HOS/ANCILLARY',
#  'HOSPICE',
#  'HOSPICE AND PALLIATIVE CARE',
#  'HOSPIT',
#  'HOSPITAL',
#  'HOSPITAL ACUTE CARE',
#  'HOSPITAL LONG TERM ACUTE CARE',
#  'HOSPITALIST',
#  'HYPBA',
#  'HYPERBARIC MEDICINE',
#  'Hand Surgery',
#  'Hearing Instrument Specialist',
#  'Hematology',
#  'Hematology / Oncology',
#  'Hematology/Oncology',
#  'Hepatology',
#  'Home Delivered Meals',
#  'Home Health Agency',
#  'Home Health Care',
#  'Hospice & Palliative Medicine',
#  'Hospice and Palliative Med',
#  'Hospital',
#  'Hospital-General',
#  'Hospitalist',
#  'Hyper Baric Treatment',
#  'Hyperbaric Medicine',
#  'IN HOME WELLNESS ASSESSME',
#  'INDEPENDENT DIAGNOSTIC TESTING FACILITY',
#  'INDEPENDENT LAB',
#  'INFECTIOUS DISEASE',
#  'INFECTIOUS DISEASES',
#  'INFUSION CARE',
#  'INFUSION PROVIDER',
#  'INP',
#  'INTERNAL MEDICINE',
#  'INTERNAL MEDICINE/GERIATRICS',
#  'INTERVENTIONAL CARDIOLOGY',
#  'INTERVENTIONAL PAIN MANAGEMENT',
#  'INTERVENTIONAL RADIOLOGY',
#  'Imaging Facility',
#  'Immunology',
#  'Independent Diagnostic Testing Facility (IDTF)',
#  'Infectious Disease',
#  'Infectious Diseases',
#  'Internal Medicine',
#  'Internal Medicine - Cardiovascular Disease\t',
#  'Internal Medicine - Clinical Cardiatric Electrophy',
#  'Internal Medicine - Critical Care Medicine\t',
#  'Internal Medicine - Endocrinology, Diabetes & Meta',
#  'Internal Medicine - Gastroenterology\t',
#  'Internal Medicine - Geriatric\t',
#  'Internal Medicine - Hematology & Oncology\t',
#  'Internal Medicine - Hepatology\t',
#  'Internal Medicine - Hospice and Palliative Medicin',
#  'Internal Medicine - Infectious Disease\t',
#  'Internal Medicine - Interventional Cardiology\t',
#  'Internal Medicine - Nephrology\t',
#  'Internal Medicine - Pulmonary Disease\t',
#  'Internal Medicine - Rheumatology\t',
#  'Interventional Cardiology',
#  'Interventional Radiology',
#  'LABORATORY',
#  'LABORATORY CENTER',
#  'LABS(CLINICAL)',
#  'LARYNGOLOGY',
#  'LCSW',
#  'LICENSED CLIN SOC WO',
#  'LICENSED CLINICAL SOCIAL WORKER',
#  'LICENSED MENTAL HLTH',
#  'LONG TERM CARE FACILITY',
#  'LONG TERM CARE HOSP',
#  'LONG TERM HOSPITAL CARE',
#  'LPC',
#  'LTAC',
#  'LTCH',
#  'Laboratory',
#  'Lic Clinical Social Worker',
#  'Licensed Counselor/Social Wrk',
#  'Long Term Care Hospital',
#  'MAMMOGRAPHY CENTER',
#  'MANIPULATIVE THERAPY',
#  'MASS IMMUNIZATION BILLER',
#  'MASSAGE THERAPIST',
#  'MASTECTOMY SUPPLIES',
#  'MAT/FETAL',
#  'MATFET',
#  'MAXILLOFACIAL SURGERY',
#  'MDWIFE',
#  'MEDDP',
#  'MEDICAL DOCTOR',
#  'MEDICAL SUPPLIER (DME)',
#  'MEDICAL SUPPLY COMPANY WITHOUT ORTHOTIST AND  PROS',
#  'MENTAL BEHAVIOR HLTH',
#  'MENTAL HEALTH',
#  'MENTAL HEALTH PROFESSIONAL',
#  'MENTAL HEALTH PROVIDER',
#  'MH',
#  'MHH',
#  'MIDWIFE',
#  'MIDWIV',
#  'MINI CLINIC',
#  'MOBIL',
#  'MOBILE DIAGNOSTIC',
#  'MRI',
#  'MRI/CAT SCAN',
#  'MSG',
#  'MULT',
#  'MULTIPLE HEALING ARTS PROFESSIONAL ASSOCIATION',
#  'Medical Oncology',
#  'Medical Supply Company with Prosthetist',
#  'Member Reimbursement',
#  'Multi Specialty Group',
#  'Multi-Specialty\t',
#  'NEOONC',
#  'NEPHROLOGY',
#  'NEUOTO',
#  'NEURA',
#  'NEURDI',
#  'NEURO PSYCH MD',
#  'NEUROLOGICAL SURGERY',
#  'NEUROLOGY',
#  'NEUROPHYSIOLOGY',
#  'NEUROPSYCHOLOGY',
#  'NEURORADIOLOGY',
#  'NEUROSURGERY',
#  'NEUROTOLOGY',
#  'NEURP',
#  'NO SPECIALTY REQUIRED',
#  'NONN',
#  'NOT MAPPED',
#  'NOTPROVIDED',
#  'NPACRE',
#  'NPAGRT',
#  'NPAHTH',
#  'NPFAM',
#  'NPGRTY',
#  'NPGYNO',
#  'NPONC',
#  'NPPSYM',
#  'NPURLO',
#  'NUCLEAR CARDIOLOGY',
#  'NUCLEAR MEDICINE',
#  'NUCRAD',
#  'NURPRC',
#  'NURSE ANESTHETIST',
#  'NURSE MIDWIFE',
#  'NURSE PRACTITIONER',
#  'NURSE PRACTITIONERS',
#  'NUTRI',
#  'NUTRITIONIST',
#  'Neonatology',
#  'Nephrology',
#  'Neuro-Psychologist',
#  'Neurological Surgery',
#  'Neurology',
#  'Neuromusculoskeletal Medicine - Sports Medicine\t',
#  'Neuropsychology',
#  'Neuroradiology',
#  'Neurosurgery',
#  'Non-Emergency Transportation',
#  'Nuclear Medicine',
#  'Nuclear Medicine\t',
#  'Nurse Anesthetist - Certified Registered\t',
#  'Nurse Practitioner',
#  'Nurse Practitioner (Arnp)',
#  'Nurse Practitioner - Acute Care\t',
#  'Nurse Practitioner - Adult Health\t',
#  'Nurse Practitioner - Family\t',
#  'Nurse Practitioner - Gerontology\t',
#  'Nurse Practitioner - Mental Health\t',
#  'Nurse Practitioner - Obstetrics & Gynecology\t',
#  'Nurse Practitioner - Primary Care\t',
#  'Nurse Practitioner Acute Care',
#  'Nurse Practnr. Adult Health',
#  'Nurse Practnr. Women Health',
#  'Nursing Home',
#  'Nutritionist',
#  'OB-GYN',
#  'OB/GYN',
#  'OB/GYN MATERNAL FETAL MEDICINE',
#  'OBS',
#  'OBSTETRICS',
#  'OBSTETRICS & GYNECOLOGY',
#  'OBSTETRICS AND GYNECOLOGY',
#  'OCCMED',
#  'OCCTHY',
#  'OCCUPATIONAL MEDICINE',
#  'OCCUPATIONAL THERAPY',
#  'OMS',
#  'ONCOLOGY',
#  'ONCOLOGY, INTERNAL MEDICINE',
#  'ONCS',
#  'OP Mental Hlth/Substance Abuse',
#  'OPHTHALMOLOGY',
#  'OPHTHAMOLOGY',
#  'OPTOMETRIST',
#  'OPTOMETRY',
#  'ORAL AND MAXILLOFACIAL SURGERY',
#  'ORT',
#  'ORTHOPAEDICS & ORTHO SURGERY',
#  'ORTHOPEDIC',
#  'ORTHOPEDIC SURGERY',
#  'ORTHOPEDICS',
#  'ORTHOTICS/PROS FITTE',
#  'ORTHOTICS/PROSTHETICS',
#  'OSTEOMANIPULATIVE MEDICINE',
#  'OSTEOPATH',
#  'OTHER',
#  'OTHER SPECIALIST',
#  'OTHERS',
#  'OTHERS/SWINGBED',
#  'OTOFPS',
#  'OTOLARYNGOLOGY',
#  'OTOLARYNGOLOGY PLASTIC SURGERY WITHIN THE HEAD & N',
#  'OTOLOGY, LARYNGOLOGY, RHINOLOGY',
#  'OTOLOGY, LARYNGOLOGY, RHINOLOGY (ENT)',
#  'OTORHI',
#  'OUT',
#  'OUT OF COUNTRY PROVIDER',
#  'OUTPATIENT MENTAL HEALTH CLINICIAN GROUP',
#  'Ob/Gyn',
#  'Obstetrics',
#  'Obstetrics & Gynecology\t',
#  'Obstetrics / Gynecology',
#  'Obstetrics And Gynecology',
#  'Occupational Medicine',
#  'Occupational Therapy',
#  'Oncology',
#  'Oncology & Hematology',
#  'Oncology (Surgical)',
#  'Ophthalmology',
#  'Ophthamology',
#  'Opthalmology',
#  'Opthalmology-Retina',
#  'Optometrist\t',
#  'Optometry',
#  'Orthopaedic Sports Medicine',
#  'Orthopaedic Surgery',
#  'Orthopedic Surgery',
#  'Orthopedic Surgery - Surgery of the Spine',
#  'Orthopedic Surgery - Trauma',
#  'Orthopedic Surgery -Sports Medicine',
#  'Orthopedics',
#  'Orthotics & Prosthetics',
#  'Osteopathic Manipulative Med',
#  'Other',
#  'Other Medical Supply Company',
#  'Otolaryngology',
#  'Otolaryngology - Plastic Surgery within the Head &',
#  'Otology / Neurotology',
#  'Otology, Laryngology, Rhinology (ENT)',
#  'PAIN MANAGEMENT',
#  'PALL',
#  'PALLIATIVE CARE',
#  'PAOTRH',
#  'PAT',
#  'PATHEM',
#  'PATHOLOGY',
#  'PAURLO',
#  'PCS',
#  'PEDANE',
#  'PEDCAR',
#  'PEDER',
#  'PEDHON',
#  'PEDIATRIC ALLERGY',
#  'PEDIATRIC CARDIOLOGY',
#  'PEDIATRIC NEPHROLOGY',
#  'PEDIATRIC PSYCHIATRY',
#  'PEDIATRIC RADIOLOGY',
#  'PEDIATRIC SURGERY',
#  'PEDIATRICIAN',
#  'PEDIATRICS',
#  'PEDIATRICS NEONATOLOGY',
#  'PEDNEP',
#  'PEDNEU',
#  'PEDNUS',
#  'PEDORT',
#  'PEDSPO',
#  'PERFUSIONIST',
#  'PERS',
#  'PERSONAL EMERGENCY RESPONSE SYSTEM',
#  'PET AND CT SCANS',
#  'PHAR',
#  'PHARMACIST AND PHARMACIES',
#  'PHARMACY',
#  'PHARMACY INFUSION THERAPY',
#  'PHARMACY WITH INFUSION THERAPY',
#  'PHGPM',
#  'PHYS MEDICINE REHAB',
#  'PHYSICAL MEDICINE & REHAB',
#  'PHYSICAL MEDICINE & REHABILITATION',
#  'PHYSICAL REHABILITATION PROFESSIONA',
#  'PHYSICAL THERAPIST',
#  'PHYSICAL THERAPY',
#  'PHYSICAL THERAPY CENTER',
#  'PHYSICIAL MEDICINE',
#  'PHYSICIAN ASSISTANT',
#  'PHYSICIAN GROUP (MD)',
#  "PHYSICIAN'S ASSISTANT",
#  'PHYSICIANS ASSISTANT',
#  'PHYSIO LAB',
#  'PLASTIC SURGERY',
#  'PLASTIC SURGERY WITHIN HEAD & NECK',
#  'PODIATRIST',
#  'PODIATRY',
#  'PODS',
#  'PORTABLE X-RAY PROVIDER (MOBILE DIAGNOSTIC)',
#  'POT',
#  'PREVENTIVE MEDICINE',
#  'PREVENTIVE MEDICINE - ADDICTION MEDICINE',
#  'PRICTR',
#  'PROCTOLOGY',
#  'PROS',
#  'PROSTHETIC & ORTHOTICS',
#  'PROSTHETIC ORTHOTIC SUPPLIER',
#  'PROV RURAL HEALTH',
#  'PROV TYPE INVALID',
#  'PRVMED',
#  'PSYARN',
#  'PSYCA',
#  'PSYCH',
#  'PSYCH & NEUROLOGY',
#  'PSYCH HOSPITAL',
#  'PSYCH UNIT',
#  'PSYCHIATRIC FAC',
#  'PSYCHIATRIC HOSP',
#  'PSYCHIATRIC HOSPITAL',
#  'PSYCHIATRY',
#  'PSYCHIATRY, NEUROLOGY',
#  'PSYCHOLOGIST',
#  'PSYCHOLOGIST - CLINICAL',
#  'PSYCHOLOGIST - REHABILITATION',
#  'PSYCHOLOGY',
#  'PSYNEU',
#  'PSYNUR',
#  'PT/OT/ST',
#  'PUBL',
#  'PULMED',
#  'PULMONARY DISEASE',
#  'PULMONARY DISEASES',
#  'PULMONARY MEDICINE',
#  'PULMONARY/CRITICAL CARE',
#  'PXRAYS',
#  'Pain Management',
#  'Pain Medicine',
#  'Pain Medicine - Interventional Pain Medicine\t',
#  'Pathology',
#  'Pathology - Anatomic - Clinic',
#  'Pathology - Anatomic Pathology\t',
#  'Pathology - Anatomic Pathology & Clinical Patholog',
#  'Pathology - Blood Banking & Transfusion Medicine\t',
#  'Pathology - Clinical',
#  'Pathology - Clinical Pathology/Laboratory Medicine',
#  'Pathology - Cytopathology\t',
#  'Pathology - Dermapathology\t',
#  'Pathology Services',
#  'Pediatric Anesthesiology',
#  'Pediatric Cardiology',
#  'Pediatric Emergency Medicine',
#  'Pediatric Medicine',
#  'Pediatric Nurse Practitioner',
#  'Pediatric Orthopaedics',
#  'Pediatric Psychiatry',
#  'Pediatric Radiology',
#  'Pediatric Rheumatology',
#  'Pediatric Surgery',
#  'Pediatrics',
#  'Pediatrics - Anesthesiology',
#  'Pediatrics - Cardiology',
#  'Pediatrics - Emergency Care',
#  'Pediatrics - Radiology',
#  'Pediatrics - Surgery',
#  'Phlebotomy',
#  'Physical Medicine & Rehabilitation',
#  'Physical Medicine and Rehab',
#  'Physical Medicine and Rehabilitation',
#  'Physical Therapist - Orthopedic\t',
#  'Physical Therapist - Pediatrics\t',
#  'Physical Therapist in Private Practice',
#  'Physical Therapy',
#  'Physician Assistant',
#  'Physician Assistant - Medical\t',
#  'Physician Assistant - Surgical\t',
#  'Physician/Allergy/ Immunology',
#  'Physician/Anesthesiology',
#  'Physician/Cardiovascular Disease (Cardiology)',
#  'Physician/Dermatology',
#  'Physician/Diagnostic Radiology',
#  'Physician/Emergency Medicine',
#  'Physician/Endocrinology',
#  'Physician/Family Practice',
#  'Physician/Gastroenterology',
#  'Physician/General Practice',
#  'Physician/General Surgery',
#  'Physician/Hematology-Oncology',
#  'Physician/Infectious Disease',
#  'Physician/Internal Medicine',
#  'Physician/Interventional Radiology',
#  'Physician/Medical Oncology',
#  'Physician/Nephrology',
#  'Physician/Neurology',
#  'Physician/Neurosurgery',
#  'Physician/Nuclear Medicine',
#  'Physician/Obstetrics & Gynecology',
#  'Physician/Ophthalmology',
#  'Physician/Orthopedic Surgery',
#  'Physician/Otolaryngology',
#  'Physician/Pain Management',
#  'Physician/Pathology',
#  'Physician/Physical Medicine and Rehabilitation',
#  'Physician/Pulmonary Disease',
#  'Physician/Rheumatology',
#  'Physician/Sports Medicine',
#  'Physician/Thoracic Surgery',
#  'Physician/Urology',
#  'Physician/Vascular Surgery',
#  'Physiological Laboratory\t',
#  'Plastic Surgery',
#  'Podiatrist\t',
#  'Podiatrist - Foot & Ankle Surgery\t',
#  'Podiatrist - Foot Surgery\t',
#  'Podiatry',
#  'Portable X Ray',
#  'Portable X-Ray Supplier',
#  'Prosthetics and Orthotics',
#  'Psych',
#  'Psychiatric Hospital',
#  'Psychiatry',
#  'Psychiatry & Neurology - Child & Adolescent Psychi',
#  'Psychiatry & Neurology - Clinical Neurophysiology\t',
#  'Psychiatry & Neurology - Geriatric Psychiatry\t',
#  'Psychiatry & Neurology - Neurology\t',
#  'Psychiatry & Neurology - Psychiatry\t',
#  'Psychiatry Neurology Osteopath',
#  'Psychologist',
#  'Psychologist\t',
#  'Psychologist - Clinical\t',
#  'Psychology',
#  'Pulmonary Diseases',
#  'Pulmonology',
#  'RACUTE',
#  'RADIATION ONCOLOGY',
#  'RADIATION THERAPY',
#  'RADIATION THERAPY CENTER',
#  'RADIOL',
#  'RADIOLOGY',
#  'RADIOLOGY CENTER',
#  'RADIOLOGY IMAGING CENTER',
#  'RADIOLOGY IMAGING PROVIDER',
#  'REGISTERED NURSE',
#  'REGISTERED NURSE (PRIVATE NURSE)',
#  'REGISTERED NURSE FIRST ASSISTANT',
#  'REGISTERED NURSE PRACTITIONER',
#  'REGISTERED PHYSICAL THERAPIST',
#  'REHAB FACILITY',
#  'REHAB HOSP',
#  'REHABILITATION',
#  'REHABILITATION CENTER',
#  'REHABILITATION FACILITY',
#  'REHABILITATION HOSPITAL',
#  'REHABILITATION UNIT',
#  'REHHOS',
#  'RENAL DIALYSIS FACILITY',
#  'RESIDENT',
#  'RESPIRATORY THERAPY',
#  'RESTPY',
#  'RHBTY',
#  'RHC',
#  'RHEUMATOLOGY',
#  'RHEUMATOLOGY, INTERNAL MEDICINE',
#  'RN',
#  'RN FIRST ASSISTANT',
#  'RURAL HEALTH CENTER',
#  'Radiation Oncology',
#  'Radiation Therapy',
#  'Radiology',
#  'Radiology\t',
#  'Radiology (Diagnostic)',
#  'Radiology - Diagnostic',
#  'Radiology - Mobile Unit',
#  'Radiology - Radiation Oncology\t',
#  'Radiology - Therapeutic',
#  'Radiology - Vascular and Interventional Radiology\t',
#  'Radiology Facility',
#  'Radiology Oncology',
#  'Radiology/Neuroradiology',
#  'Reciprocity Physician',
#  'Reg Nurse First Assistant',
#  'Registered Nurse',
#  'Registered Nurse First Assistant',
#  'Rehabilitation Center',
#  'Reproductive Endocrinology',
#  'Rheumatology',
#  'Rheumatology, Internal Medicine',
#  'SKILLED NURSING FAC',
#  'SKILLED NURSING FACILITY',
#  'SKILLED NURSING UNIT',
#  'SLEEP CENTER',
#  'SLEEP DIAGNOSTIC CENTER',
#  'SLEEP DIAGNOSTIC FACILITY',
#  'SLEEP MEDICINE',
#  'SLEEP STUDY CENTER FACILITY',
#  'SNF',
#  'SOCIAL WORKER',
#  'SPC FCLY / CA HOSPITAL',
#  'SPECIAL SERVICES',
#  'SPEECH THERAPIST',
#  'SPEECH THERAPY',
#  'SPHEAR',
#  'SPINAL CORD INJURY MD',
#  'SPINAL CORD INJURY MEDICINE',
#  'SPORTS MEDICINE',
#  'SPTMED',
#  'SPTSUR',
#  'STATE HOSPITAL',
#  'SUBST',
#  'SUBSTANCE ABUSE FACILITY',
#  'SUCRIT',
#  'SUORSP',
#  'SUPLRE',
#  'SURG CRITICAL CARE',
#  'SURGC',
#  'SURGERY',
#  'SURGERY ONCOLOGY',
#  'SURGERY-OB/GYN',
#  'SURGICAL CENTER',
#  'SURGICAL CRITICAL CARE',
#  'SURGICAL ONCOLOGY',
#  'SURGO',
#  'Skilled Nursing Facility',
#  'Skilled Nursing Facility\t',
#  'Skilled Nursing Home',
#  'Sleep Disorder Clinic',
#  'Sleep Medicine',
#  'Social Worker',
#  'Special(ty) Hospital\t',
#  'Specialty Pharmacies',
#  'Speech Therapy',
#  'Sports Medicine',
#  'Surgery',
#  'Surgery (Cardiothoracic)',
#  'Surgery (Plastic)',
#  'Surgery (Thoracic)',
#  'Surgery (Vascular)',
#  'Surgery - Cardiothoracic',
#  'Surgery - Cardiovascular',
#  'Surgery - Colon & Rectal',
#  'Surgery - Critical Care\t',
#  'Surgery - General',
#  'Surgery - Hand',
#  'Surgery - Neurological',
#  'Surgery - Oncology',
#  'Surgery - Orthopedic',
#  'Surgery - Plastic',
#  'Surgery - Plastic and Reconstructive\t',
#  'Surgery - Thoracic',
#  'Surgery - Trauma',
#  'Surgery - Vascular',
#  'Surgery - Vascular\t',
#  'Surgery Orthopedic - Sports Medicine',
#  'Surgery of the Hand',
#  'Surgery, Cardiovascular',
#  'Surgery, General',
#  'Surgery, Oncologic',
#  'Surgery, Transplant',
#  'Surgical Assistant Employer',
#  'Surgical Critical Care',
#  'TBICRS',
#  'THERAPEUTIC RADIOLOGY',
#  'THERAPY',
#  'THERAPY CENTER SPEECH OCCUPATIONAL AND PHYSICAL',
#  'THERO',
#  'THERR',
#  'THORACIC & CARDIOVASCULAR SURGERY',
#  'THORACIC SURGERY',
#  'THORACIC/CARDIOTHORACIC VASCULAR SURGERY',
#  'TRANSPLANT HEPATOLOGY',
#  'TRANSPLANT SURGEON',
#  'TRANSPLANT SURGERY',
#  'TRANSPORTATION',
#  'TRASUR',
#  'TRAUMA SURGERY',
#  'TSG',
#  'TSURGE',
#  'TVS',
#  'Technician - Other',
#  'Telemedicine',
#  'Therapeutic Radiology',
#  'Thoracic Surgery',
#  'Thoracic and Cardiovascular Surgery',
#  'Transplant Hepatology',
#  'Transportation',
#  'Traumatic Surgery',
#  'UNDER',
#  'UNDERSEA AND HYPERBARIC MEDICINE',
#  'URGENT CARE CENTER',
#  'URGENT CARE MEDICINE',
#  'UROGYN',
#  'UROGYNECOLOGY',
#  'UROLOGY',
#  'UROONC',
#  'Unclassified Non-Physician',
#  'Unknown',
#  'Unknown MD',
#  'Urgent Care Center',
#  'Urgent Care Facility',
#  'Urology',
#  'VASCU',
#  'VASCUL',
#  'VASCULAR & INTERVENTIONAL RADIOLOGY',
#  'VASCULAR NEUROLOGY',
#  'VASCULAR SURGERY',
#  'VASNEU',
#  'VASURG',
#  'VISION',
#  'Vascular & Interventional Rad',
#  'Vascular Surgery',
#  'WOUND',
#  'WOUND CARE SPECIALISTS',
#  'WOUNDCARE',
#  'WOUNDCARE PHYSICIAN',
#  'Walk-In Clinic',
#  'Wound Care Center',
#  'X - Technician/Technologist - Optician',
#  'null_specialty']

# %% [markdown]
# - similar lower and uppercase specialties <br>
# - \t confusing symbols <br>
# - claim specialties with very similar names like 'EMERGENCY MEDICINE, GEN PRACTICE' and 'EMERGENCY MEDICINE, GENERAL PRACTICE'

# %% [markdown]
# ## Group similar specialties

# %%
df['CLAIM_SPECIALTY_formatted'] = df['CLAIM_SPECIALTY'].apply(lambda x: x.lower())

# %%
df['CLAIM_SPECIALTY_formatted'] = df['CLAIM_SPECIALTY_formatted'].apply(lambda x: x.replace('\t', ''))

# %%
print("Unique Claim Specialty: ", len(df['CLAIM_SPECIALTY_formatted'].unique()))
# Out:
# Unique Claim Specialty:  786

# %%
claims = df['CLAIM_SPECIALTY_formatted'].unique()

# %% [markdown]
# ## Find very similar claim specialty groups

# %%
from collections import Counter

stripJunk = str.maketrans("","","- ")

def getRatio(a,b):
    a = a.lower().translate(stripJunk)
    b = b.lower().translate(stripJunk)
    total  = len(a)+len(b)
    counts = (Counter(a)-Counter(b))+(Counter(b)-Counter(a))
    return 100 - 100 * sum(counts.values()) / total

# %%
# %time
data = claims

treshold     = 90
minGroupSize = 1

from itertools import combinations

paired = { c:{c} for c in data }
for a,b in combinations(data,2):
    if getRatio(a,b) < treshold: continue
    paired[a].add(b)
    paired[b].add(a)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.25 µs

# %%
paired
# Out:
# {'null_specialty': {'null_specialty'},
#  'ach': {'ach'},
#  'advanced registered nurse prac': {'advanced registered nurse prac'},
#  'advanced rn pract': {'advanced rn pract'},
#  'ambulance': {'ambulance'},
#  'ambulance service': {'ambulance service'},
#  'ambulatory surgical center': {'abulatory surgical center',
#   'ambulatory surgical center',
#   'ambulatory surgical centers'},
#  'ambulatory transportation services': {'ambulatory transportation services'},
#  'anatom': {'anatom'},
#  'anesthesiology': {'anesthesiology'},
#  'arnp': {'aprn', 'arnp'},
#  'behavioral health counseling': {'behavioral health counseling'},
#  'card electrophysiolo': {'card electrophysiolo'},
#  'cardiac electrophysiology': {'cardiac electrophysiology'},
#  'cardiology': {'cardiology', 'radiology'},
#  'cardiology/cardiovascular disease': {'cardiology/cardiovascular disease'},
#  'cardiovascular medicine': {'cardiovascular medicine'},
#  'cardiovascular surgery': {'cardiovascular surgery',
#   'surgery - cardiovascular',
#   'surgery, cardiovascular'},
#  'ccs': {'ccs'},
#  'chiropractic medicine': {'chiropractic medicine'},
#  'clinical medical laboratory': {'clinical medical laboratory'},
#  'colon and rectal surgery': {'colon & rectal surgery',
#   'colon / rectal surgery',
#   'colon and rectal surgery',
#   'colon/rectal surgery',
#   'surgery - colon & rectal'},
#  'community mental health center': {'community mental health center'},
#  'community mental health center/other rehab center': {'community mental health center/other rehab center'},
#  'conv care clinic': {'conv care clinic'},
#  'covering physician': {'covering physician'},
#  'critical access': {'critical access'},
#  'csw': {'csw'},
#  'default': {'default'},
#  'dermatology': {'dermatology'},
#  'dermatopathology': {'dermatopathology'},
#  'diabetes educator': {'diabetes educator'},
#  'diag x-ray clinic': {'diag x-ray clinic'},
#  'diagnostic radiology': {'diagnostic radiology',
#   'radiology (diagnostic)',
#   'radiology - diagnostic'},
#  'diagnostics': {'diagnostics'},
#  'dial': {'dial'},
#  'dialysis': {'dialysis'},
#  'dialysis center': {'dialysis center'},
#  'disease management': {'disease management'},
#  'dme & medical supplies, oxygen equip & supplies': {'dme & medical supplies, oxygen equip & supplies'},
#  'doctor of psychology': {'doctor of psychology'},
#  'durable med equipment': {'durable med equipment',
#   'durable medical equipment'},
#  'durable medical equipment': {'durable med equipment',
#   'durable medical equipment'},
#  'durable medical supply': {'durable medical supply'},
#  'emergency medicine': {'emergency medicine'},
#  'emergency room': {'emergency room'},
#  'end-stage renal disease (esrd) treatment': {'end-stage renal disease (esrd) treatment'},
#  'endocrinology': {'endocrinology'},
#  'ent': {'ent'},
#  'family nurse practioner': {'family nurse practioner',
#   'nurse practitioner - family'},
#  'family practice': {'family practice'},
#  'fitness': {'fitness'},
#  'fqhc': {'fqhc'},
#  'gastroenterology': {'gastroenterology'},
#  'general practice': {'general practice'},
#  'general surgery': {'general surgery',
#   'surgery - general',
#   'surgery, general'},
#  'geriatric medicine': {'geriatric medicine'},
#  'geriatrics': {'geriatrics'},
#  'gynecology': {'gynecology', 'gynecology -in'},
#  'hearing services': {'hearing services'},
#  'hematology/oncology': {'hematology / oncology',
#   'hematology/oncology',
#   'oncology & hematology'},
#  'home delivered meals': {'home delivered meals'},
#  'home health': {'home health'},
#  'home health agency': {'home health agency'},
#  'home health care': {'home health care'},
#  'home health center': {'home health center'},
#  'hos/ancillary': {'hos/ancillary'},
#  'hospice': {'hospice'},
#  'hospital': {'hospital'},
#  'hospital acute care': {'acute care hospital', 'hospital acute care'},
#  'hospitalist': {'hospitalist'},
#  'hyperbaric medicine': {'hyperbaric medicine'},
#  'independent lab': {'independent lab'},
#  'infectious disease': {'infectious disease', 'infectious diseases'},
#  'infectious diseases': {'infectious disease', 'infectious diseases'},
#  'infusion care': {'infusion care'},
#  'infusion provider': {'infusion provider'},
#  'internal medicine': {'internal medicine'},
#  'interventional cardiology': {'interventional cardiology',
#   'interventional radiology'},
#  'laboratory': {'laboratory'},
#  'labs(clinical)': {'labs(clinical)'},
#  'medical doctor': {'medical doctor'},
#  'medical supplier (dme)': {'medical supplier (dme)'},
#  'mental health': {'mental health'},
#  'mental health professional': {'mental health professional'},
#  'mhh': {'mhh'},
#  'mini clinic': {'mini clinic'},
#  'mobil': {'mobil'},
#  'mobile diagnostic': {'diagnostics (mobile)', 'mobile diagnostic'},
#  'nephrology': {'nephrology'},
#  'neurological surgery': {'neurological surgery', 'surgery - neurological'},
#  'neurology': {'neurology', 'neurotology'},
#  'neurosurgery': {'neurosurgery'},
#  'non-emergency transportation': {'non-emergency transportation'},
#  'notprovided': {'notprovided'},
#  'nurse practitioner': {'nurse practitioner', 'nurse practitioners'},
#  'nurse practitioner (arnp)': {'nurse practitioner (arnp)'},
#  'nurse practitioners': {'nurse practitioner', 'nurse practitioners'},
#  'obstetrics & gynecology': {'gynecology - no obstetrics',
#   'obstetrics & gynecology',
#   'obstetrics / gynecology',
#   'obstetrics and gynecology'},
#  'obstetrics and gynecology': {'gynecology - no obstetrics',
#   'obstetrics & gynecology',
#   'obstetrics / gynecology',
#   'obstetrics and gynecology'},
#  'oncology': {'oncology'},
#  'oncology & hematology': {'hematology / oncology',
#   'hematology/oncology',
#   'oncology & hematology'},
#  'ophthalmology': {'ophthalmology', 'ophthamology', 'opthalmology'},
#  'opthalmology': {'ophthalmology', 'ophthamology', 'opthalmology'},
#  'optometry': {'optometry'},
#  'orthopedic': {'orthopedic', 'orthopedics'},
#  'orthopedic surgery': {'orthopaedic surgery',
#   'orthopedic surgery',
#   'surgery - orthopedic'},
#  'orthopedics': {'orthopedic', 'orthopedics'},
#  'orthotics/prosthetics': {'orthotics & prosthetics',
#   'orthotics/pros fitte',
#   'orthotics/prosthetics',
#   'prosthetic & orthotics',
#   'prosthetics and orthotics'},
#  'osteopath': {'osteopath'},
#  'other': {'other', 'others', 'thero'},
#  'others': {'other', 'others', 'thero'},
#  'out of country provider': {'out of country provider'},
#  'pain management': {'pain management'},
#  'pathology': {'hepatology', 'pathology'},
#  'pathology - anatomic pathology & clinical patholog': {'pathology - anatomic pathology & clinical patholog'},
#  'pcs': {'pcs'},
#  'pediatrics': {'pediatrics'},
#  'personal emergency response system': {'personal emergency response system'},
#  'pharmacy': {'pharmacy'},
#  'phys medicine rehab': {'phys medicine rehab'},
#  'physical medicine & rehab': {'physical medicine & rehab',
#   'physical medicine and rehab'},
#  'physical therapy': {'physical therapy'},
#  'physician assistant': {'physician assistant',
#   "physician's assistant",
#   'physicians assistant'},
#  'plastic surgery': {'plastic surgery',
#   'surgery (plastic)',
#   'surgery - plastic'},
#  'podiatrist': {'podiatrist'},
#  'podiatrist - foot surgery': {'podiatrist - foot surgery'},
#  'podiatry': {'podiatry'},
#  'preventive medicine': {'preventive medicine'},
#  'prosthetic & orthotics': {'orthotics & prosthetics',
#   'orthotics/prosthetics',
#   'prosthetic & orthotics'},
#  'prosthetics and orthotics': {'orthotics & prosthetics',
#   'orthotics/prosthetics',
#   'prosthetics and orthotics'},
#  'prov rural health': {'prov rural health'},
#  'prov type invalid': {'prov type invalid'},
#  'psych hospital': {'psych hospital'},
#  'psychiatry': {'psychiatry'},
#  'psychology': {'psychology'},
#  'publ': {'publ'},
#  'pulmonary disease': {'pulmonary disease', 'pulmonary diseases'},
#  'pulmonary diseases': {'pulmonary disease', 'pulmonary diseases'},
#  'pulmonology': {'pulmonology'},
#  'radiation oncology': {'radiation oncology'},
#  'radiology': {'cardiology', 'radiology'},
#  'radiology (diagnostic)': {'diagnostic radiology',
#   'radiology (diagnostic)',
#   'radiology - diagnostic'},
#  'radiology - diagnostic': {'diagnostic radiology',
#   'radiology (diagnostic)',
#   'radiology - diagnostic'},
#  'radiology imaging center': {'radiology imaging center'},
#  'radiology imaging provider': {'radiology imaging provider'},
#  'radiology oncology': {'radiology oncology'},
#  'rehabilitation center': {'rehabilitation center'},
#  'rehabilitation facility': {'rehabilitation facility'},
#  'rehabilitation hospital': {'rehabilitation hospital'},
#  'renal dialysis facility': {'renal dialysis facility'},
#  'rheumatology': {'hematology', 'rheumatology'},
#  'skilled nursing facility': {'skilled nursing facility'},
#  'sleep center': {'sleep center'},
#  'sleep diagnostic facility': {'sleep diagnostic facility'},
#  'sleep medicine': {'sleep medicine'},
#  'spc fcly / ca hospital': {'spc fcly / ca hospital'},
#  'special services': {'special services'},
#  'subst': {'subst'},
#  'surgery (vascular)': {'surgery (vascular)',
#   'surgery - vascular',
#   'vascular surgery'},
#  'surgical oncology': {'oncology (surgical)', 'surgical oncology'},
#  'therr': {'therr'},
#  'transportation': {'transportation'},
#  'under': {'neurdi', 'under'},
#  'urgent care center': {'urgent care center'},
#  'urgent care facility': {'urgent care facility'},
#  'urgent care medicine': {'urgent care medicine'},
#  'urology': {'urology'},
#  'vascular surgery': {'surgery (vascular)',
#   'surgery - vascular',
#   'vascular surgery'},
#  'vision': {'vision'},
#  'wound care specialists': {'wound care specialists'},
#  'woundcare': {'woundcare'},
#  'abulatory surgical center': {'abulatory surgical center',
#   'ambulatory surgical center',
#   'ambulatory surgical centers'},
#  'ambulatory surgery center': {'ambulatory surgery center'},
#  'ambulatory surgical centers': {'abulatory surgical center',
#   'ambulatory surgical center',
#   'ambulatory surgical centers'},
#  'anes assist': {'anes assist'},
#  'anesthesiologist': {'anesthesiologist'},
#  'asc': {'asc'},
#  'certified registered nurse anesthetist': {'certified registered nurse anesthetist',
#   'certified registered nurse anesthetist (crna)',
#   'nurse anesthetist - certified registered'},
#  'hand surgery': {'hand surgery', 'surgery - hand'},
#  'nurse anesthetist': {'anesthetist, nurse', 'nurse anesthetist'},
#  'nurse anesthetist - certified registered': {'certified registered nurse anesthetist',
#   'certified registered nurse anesthetist (crna)',
#   'nurse anesthetist - certified registered'},
#  'ophthamology': {'ophthalmology', 'ophthamology', 'opthalmology'},
#  'pedane': {'pedane'},
#  'pediatrics - anesthesiology': {'pediatric anesthesiology',
#   'pediatrics - anesthesiology'},
#  'physical medicine & rehabilitation': {'physical medicine & rehabilitation',
#   'physical medicine and rehabilitation'},
#  'sptmed': {'sptmed'},
#  'surgery - hand': {'hand surgery', 'surgery - hand'},
#  'surgical center': {'surgical center'},
#  'urogynecology': {'surgery - oncology', 'surgery oncology', 'urogynecology'},
#  'x - technician/technologist - optician': {'x - technician/technologist - optician'},
#  'cardiothoracic surgery': {'cardiothoracic surge',
#   'cardiothoracic surgery',
#   'surgery (cardiothoracic)',
#   'surgery - cardiothoracic'},
#  'clinic': {'clinic'},
#  'clmis': {'clmis'},
#  'electrophysiologic study': {'electrophysiologic study'},
#  'emergency medicine, general practice': {'emergency medicine, gen practice',
#   'emergency medicine, general practice'},
#  'internal medicine - cardiovascular disease': {'internal medicine - cardiovascular disease'},
#  'interventional radiology': {'interventional cardiology',
#   'interventional radiology'},
#  'mult': {'mult'},
#  'neura': {'neura'},
#  'neuroradiology': {'neuroradiology'},
#  'nuclear medicine': {'nuclear medicine'},
#  'out': {'out'},
#  "physician's assistant": {'physician assistant',
#   "physician's assistant",
#   'physicians assistant'},
#  'radiol': {'radiol'},
#  'resident': {'resident'},
#  'surgery - cardiovascular': {'cardiovascular surgery',
#   'surgery - cardiovascular',
#   'surgery, cardiovascular'},
#  'surgery - general': {'general surgery',
#   'surgery - general',
#   'surgery, general'},
#  'vascular & interventional radiology': {'vascular & interventional radiology'},
#  'allergy & immunology': {'allergy & immunology',
#   'allergy / immunology',
#   'allergy/immunology'},
#  'allergy / immunology': {'allergy & immunology',
#   'allergy / immunology',
#   'allergy/immunology'},
#  'audiology': {'audiology'},
#  'carde': {'carde', 'pedcar'},
#  'cardiothoracic surge': {'cardiothoracic surge',
#   'cardiothoracic surgery',
#   'surgery (cardiothoracic)',
#   'surgery - cardiothoracic'},
#  'cert first assistant': {'cert first assistant'},
#  'colon / rectal surgery': {'colon & rectal surgery',
#   'colon / rectal surgery',
#   'colon and rectal surgery',
#   'colon/rectal surgery',
#   'colorectal surgery',
#   'surgery - colon & rectal'},
#  'colorectal surgery': {'colon & rectal surgery',
#   'colon / rectal surgery',
#   'colon/rectal surgery',
#   'colorectal surgery',
#   'surgery - colon & rectal'},
#  'critical care': {'critical care'},
#  'critical care medicine': {'critical care medicine'},
#  'cvs': {'cvs'},
#  'durable med eqt&med suppl/cardiologist': {'durable med eqt&med suppl/cardiologist'},
#  'emergency medicine - emergency medical services': {'emergency medicine - emergency medical services'},
#  'general acute care hospital': {'general acute care hospital'},
#  'general specialist': {'general specialist'},
#  'gynecologic oncology': {'gynecologic oncology', 'gynecological oncology'},
#  'hematology': {'hematology', 'hepatology', 'rheumatology'},
#  'hospice and palliative care': {'hospice and palliative care'},
#  'inp': {'inp'},
#  'internal medicine - clinical cardiatric electrophy': {'internal medicine - clinical cardiatric electrophy'},
#  'internal medicine - gastroenterology': {'internal medicine - gastroenterology'},
#  'internal medicine - interventional cardiology': {'internal medicine - interventional cardiology'},
#  'internal medicine - pulmonary disease': {'internal medicine - pulmonary disease'},
#  'multi-specialty': {'multi-specialty'},
#  'neurophysiology': {'neurophysiology', 'neuropsychology'},
#  'neuropsychology': {'neurophysiology',
#   'neuropsychology',
#   'psych & neurology'},
#  'npacre': {'npacre'},
#  'nucrad': {'nucrad'},
#  'nurse practitioner - family': {'family nurse practioner',
#   'nurse practitioner - family'},
#  'ort': {'ort'},
#  'pathology - anatomic pathology': {'pathology - anatomic pathology'},
#  'pediatric surgery': {'pediatric surgery', 'pediatrics - surgery'},
#  'pediatrics - radiology': {'pediatric cardiology',
#   'pediatric radiology',
#   'pediatrics - cardiology',
#   'pediatrics - radiology'},
#  'pediatrics - surgery': {'pediatric surgery', 'pediatrics - surgery'},
#  'physical therapist': {'physical therapist'},
#  'psychiatric hosp': {'psychiatric hosp'},
#  'psychiatric hospital': {'psychiatric hospital'},
#  'psychiatry & neurology - neurology': {'psychiatry & neurology - neurology'},
#  'psychologist - clinical': {'psychologist - clinical'},
#  'pulmonary medicine': {'pulmonary medicine'},
#  'radiology - vascular and interventional radiology': {'radiology - vascular and interventional radiology'},
#  'registered nurse practitioner': {'registered nurse practitioner'},
#  'rehab facility': {'rehab facility'},
#  'sports medicine': {'sports medicine'},
#  'surgery - neurological': {'neurological surgery', 'surgery - neurological'},
#  'surgery - oncology': {'surgery - oncology',
#   'surgery oncology',
#   'urogynecology'},
#  'surgery - thoracic': {'surgery (thoracic)',
#   'surgery - thoracic',
#   'thoracic surgery'},
#  'surgical critical care': {'surgical critical care'},
#  'technician - other': {'technician - other'},
#  'thoracic & cardiovascular surgery': {'thoracic & cardiovascular surgery',
#   'thoracic and cardiovascular surgery'},
#  'thoracic surgery': {'surgery (thoracic)',
#   'surgery - thoracic',
#   'thoracic surgery'},
#  'transplant hepatology': {'transplant hepatology'},
#  'transplant surgery': {'surgery, transplant', 'transplant surgery'},
#  'tsurge': {'tsurge'},
#  'undersea and hyperbaric medicine': {'undersea and hyperbaric medicine'},
#  'ambulatory health care': {'ambulatory health care'},
#  'cladc': {'cladc'},
#  'group of providers': {'group of providers'},
#  'maxillofacial surgery': {'maxillofacial surgery'},
#  'neoonc': {'neoonc'},
#  'oncology (surgical)': {'oncology (surgical)', 'surgical oncology'},
#  'otolaryngology': {'otolaryngology'},
#  'otolaryngology plastic surgery within the head & n': {'otolaryngology - plastic surgery within the head &',
#   'otolaryngology plastic surgery within the head & n'},
#  'pedcar': {'carde', 'pedcar'},
#  'pedhon': {'pedhon'},
#  'psychiatry & neurology - child & adolescent psychi': {'psychiatry & neurology - child & adolescent psychi'},
#  'registered nurse': {'registered nurse'},
#  'surgc': {'surgc'},
#  'surgery - orthopedic': {'orthopaedic surgery',
#   'orthopedic surgery',
#   'surgery - orthopedic'},
#  'surgery oncology': {'surgery - oncology',
#   'surgery oncology',
#   'urogynecology'},
#  'wound': {'wound'},
#  'woundcare physician': {'woundcare physician'},
#  'advanced registered nurse practitioner': {'advanced registered nurse practitioner'},
#  'diagnostic imaging': {'diagnostic imaging'},
#  'family medicine - adult medicine': {'family medicine - adult medicine'},
#  'physical medicine and rehabilitation': {'physical medicine & rehabilitation',
#   'physical medicine and rehabilitation'},
#  'skilled nursing fac': {'skilled nursing fac'},
#  'snf': {'snf'},
#  'allergy/immunology': {'allergy & immunology',
#   'allergy / immunology',
#   'allergy/immunology'},
#  'critical/intensive care med': {'critical/intensive care med'},
#  'ent/otolaryngology': {'ent/otolaryngology'},
#  'surgery (plastic)': {'plastic surgery',
#   'surgery (plastic)',
#   'surgery - plastic'},
#  'anatomic and clinical pathology': {'anatomic and clinical pathology',
#   'pathology - anatomic - clinic'},
#  'chiropractic': {'chiropractic'},
#  'chiropractor': {'chiropractor'},
#  'clinical neuropsychologist': {'clinical neuropsychologist'},
#  'clinical nurse specialist - adult health': {'clinical nurse specialist - adult health'},
#  'dental': {'dental'},
#  'dental general': {'dental general'},
#  'dentist': {'dentist'},
#  'dermatology - pathology': {'dermatology - pathology',
#   'pathology - dermapathology'},
#  'diagnostic center': {'diagnostic center'},
#  'gyne': {'gyne'},
#  'gynecology -in': {'gynecology', 'gynecology -in'},
#  'hepatitis': {'hepatitis'},
#  'home infusion': {'home infusion'},
#  'independent diagnostic testing facility': {'independent diagnostic testing facility',
#   'independent diagnostic testing facility (idtf)'},
#  'internal medicine - endocrinology, diabetes & meta': {'internal medicine - endocrinology, diabetes & meta'},
#  'internal medicine - rheumatology': {'internal medicine - hepatology',
#   'internal medicine - rheumatology',
#   'rheumatology, internal medicine'},
#  'licensed clin soc wo': {'licensed clin soc wo'},
#  'licensed clinical social worker': {'lic clinical social worker',
#   'licensed clinical social worker'},
#  'mri/cat scan': {'mri/cat scan'},
#  'npfam': {'npfam'},
#  'nurse midwife': {'nurse midwife'},
#  'nurse practitioner - acute care': {'nurse practitioner - acute care',
#   'nurse practitioner acute care'},
#  'nurse practitioner - adult health': {'nurse practitioner - adult health',
#   'nurse practitioner - mental health'},
#  'ob-gyn': {'ob-gyn', 'ob/gyn'},
#  'ob/gyn': {'ob-gyn', 'ob/gyn'},
#  'obs': {'obs'},
#  'obstetrics': {'obstetrics'},
#  'occupational therapy': {'occupational therapy'},
#  'oms': {'oms'},
#  'optometrist': {'optometrist'},
#  'oral and maxillofacial surgery': {'dental-oral maxillofacial surg',
#   'oral and maxillofacial surgery'},
#  'orthopedic surgery - surgery of the spine': {'orthopedic surgery - surgery of the spine'},
#  'other specialist': {'other specialist'},
#  'otology, laryngology, rhinology (ent)': {'otology, laryngology, rhinology',
#   'otology, laryngology, rhinology (ent)'},
#  'pain medicine - interventional pain medicine': {'pain medicine - interventional pain medicine'},
#  'pediatric medicine': {'pediatric medicine'},
#  'pediatric nephrology': {'pediatric nephrology'},
#  'pediatric psychiatry': {'pediatric psychiatry'},
#  'pediatrician': {'pediatrician'},
#  'pednep': {'pednep'},
#  'physician assistant - medical': {'physician assistant - medical'},
#  'physician assistant - surgical': {'physician assistant - surgical'},
#  'physio lab': {'physio lab'},
#  'podiatrist - foot & ankle surgery': {'podiatrist - foot & ankle surgery'},
#  'proctology': {'proctology'},
#  'psychologist': {'psychologist'},
#  'radiation therapy': {'radiation therapy'},
#  'rhbty': {'rhbty'},
#  'rheumatology, internal medicine': {'internal medicine - hepatology',
#   'internal medicine - rheumatology',
#   'rheumatology, internal medicine'},
#  'speech therapist': {'speech therapist'},
#  'spinal cord injury md': {'spinal cord injury md'},
#  'spinal cord injury medicine': {'spinal cord injury medicine'},
#  'surg critical care': {'surg critical care', 'surgery - critical care'},
#  'surgery - colon & rectal': {'colon & rectal surgery',
#   'colon / rectal surgery',
#   'colon and rectal surgery',
#   'colon/rectal surgery',
#   'colorectal surgery',
#   'surgery - colon & rectal'},
#  'therapeutic radiology': {'pediatric rheumatology',
#   'radiology - therapeutic',
#   'therapeutic radiology'},
#  'therapy': {'therapy'},
#  'thero': {'other', 'others', 'thero'},
#  'urogyn': {'urogyn'},
#  'ambulance - land': {'ambulance - land'},
#  'clinlb': {'clinlb'},
#  'nurse practitioner - mental health': {'nurse practitioner - adult health',
#   'nurse practitioner - mental health'},
#  'portable x-ray supplier': {'portable x-ray supplier'},
#  'sleep study center facility': {'sleep study center facility'},
#  'rehab hosp': {'rehab hosp'},
#  'respiratory therapy': {'respiratory therapy'},
#  'vascu': {'vascu', 'vascul'},
#  'diagnostics(sleep studies lab)': {'diagnostics(sleep studies lab)'},
#  'internal medicine - critical care medicine': {'internal medicine - critical care medicine'},
#  'internal medicine - infectious disease': {'internal medicine - infectious disease'},
#  'internal medicine - nephrology': {'internal medicine - hepatology',
#   'internal medicine - nephrology'},
#  'neurotology': {'neurology', 'neurotology'},
#  'orthopedic surgery - trauma': {'orthopedic surgery - trauma'},
#  'palliative care': {'palliative care'},
#  'pathology - clinical': {'clinical pathology', 'pathology - clinical'},
#  'psychiatric fac': {'psychiatric fac'},
#  'psyneu': {'psyneu'},
#  'rn first assistant': {'rn first assistant'},
#  'substance abuse facility': {'substance abuse facility'},
#  'surgery (thoracic)': {'surgery (thoracic)',
#   'surgery - thoracic',
#   'thoracic surgery'},
#  'surgery - critical care': {'surg critical care', 'surgery - critical care'},
#  'surgery - trauma': {'surgery - trauma', 'trauma surgery'},
#  'trasur': {'trasur'},
#  'vasurg': {'vasurg'},
#  'endocrinology, internal medicine': {'endocrinology, internal medicine',
#   'oncology, internal medicine'},
#  'gasthp': {'gasthp'},
#  'osteomanipulative medicine': {'osteomanipulative medicine'},
#  'pediatric radiology': {'pediatric cardiology',
#   'pediatric radiology',
#   'pediatrics - cardiology',
#   'pediatrics - radiology'},
#  'surgery - plastic and reconstructive': {'surgery - plastic and reconstructive'},
#  'dental-oral maxillofacial surg': {'dental-oral maxillofacial surg',
#   'oral and maxillofacial surgery'},
#  'opthalmology-retina': {'opthalmology-retina'},
#  'radiology/neuroradiology': {'radiology/neuroradiology'},
#  'cardiac monitoring': {'cardiac monitoring'},
#  'carv': {'carv'},
#  'chadp': {'chadp'},
#  'cytopa': {'cytopa'},
#  'gynecological oncology': {'gynecologic oncology', 'gynecological oncology'},
#  'lcsw': {'lcsw'},
#  'neuromusculoskeletal medicine - sports medicine': {'neuromusculoskeletal medicine - sports medicine'},
#  'nurprc': {'nurprc'},
#  'occthy': {'occthy'},
#  'pet and ct scans': {'pet and ct scans'},
#  'radiology - therapeutic': {'pediatric rheumatology',
#   'radiology - therapeutic',
#   'therapeutic radiology'},
#  'registered nurse first assistant': {'registered nurse first assistant'},
#  'surgery - plastic': {'plastic surgery',
#   'surgery (plastic)',
#   'surgery - plastic'},
#  'surgery - vascular': {'surgery (vascular)',
#   'surgery - vascular',
#   'vascular surgery'},
#  'clinical social work': {'clinical social work', 'clinical social worker'},
#  'hearing aid center': {'hearing aid center'},
#  'hinf': {'hinf'},
#  'lpc': {'lpc'},
#  'member reimbursement': {'member reimbursement'},
#  'pathology - dermapathology': {'dermatology - pathology',
#   'pathology - dermapathology'},
#  'prvmed': {'prvmed'},
#  'radiology - radiation oncology': {'radiology - radiation oncology'},
#  'social worker': {'social worker'},
#  'certified nurse anesthetist': {'certified nurse anesthetist'},
#  'acute care hospital': {'acute care hospital', 'hospital acute care'},
#  'emergency medicine - medical toxicology': {'emergency medicine - medical toxicology'},
#  'surgical assistant employer': {'surgical assistant employer'},
#  'adlmed': {'adlmed'},
#  'dental oral surgery': {'dental oral surgery'},
#  'hapc': {'hapc'},
#  'hmo': {'hmo'},
#  'internal medicine - hematology & oncology': {'internal medicine - hematology & oncology'},
#  'nurse practitioner - gerontology': {'gynecology nurse practitioner',
#   'nurse practitioner - gerontology'},
#  'nurse practitioner - primary care': {'nurse practitioner - primary care'},
#  'perfusionist': {'perfusionist'},
#  'psychiatry & neurology - clinical neurophysiology': {'psychiatry & neurology - clinical neurophysiology'},
#  'tsg': {'tsg'},
#  'hdnck': {'hdnck'},
#  'no specialty required': {'no specialty required'},
#  'pedneu': {'pedneu'},
#  'anesthesiology - pain medicine': {'anesthesiology - pain medicine'},
#  'clin': {'clin'},
#  'licensed mental hlth': {'licensed mental hlth'},
#  'mammography center': {'mammography center'},
#  'mri': {'mri'},
#  'neuoto': {'neuoto'},
#  'npgrty': {'npgrty'},
#  'nutritionist': {'nutritionist'},
#  'registered physical therapist': {'registered physical therapist'},
#  'analytical labs': {'analytical labs'},
#  'config - amr': {'config - amr'},
#  'pharmacist and pharmacies': {'pharmacist and pharmacies'},
#  'anesthesiologist assistant': {'anesthesiologist assistant'},
#  'general clinic': {'general clinic'},
#  'internal medicine - geriatric': {'internal medicine - geriatric',
#   'internal medicine/geriatrics'},
#  'ltac': {'ltac'},
#  'nuclear cardiology': {'nuclear cardiology'},
#  'surgery (cardiothoracic)': {'cardiothoracic surge',
#   'cardiothoracic surgery',
#   'surgery (cardiothoracic)',
#   'surgery - cardiothoracic'},
#  'hemp': {'hemp'},
#  'pediatrics - cardiology': {'pediatric cardiology',
#   'pediatric radiology',
#   'pediatrics - cardiology',
#   'pediatrics - radiology'},
#  'audiologist': {'audiologist'},
#  'bariatric surgery': {'bariatric surgery'},
#  'dietician': {'dietician'},
#  'dietitian, registered': {'dietician - registered', 'dietitian, registered'},
#  'emergency medicine, gen practice': {'emergency medicine, gen practice',
#   'emergency medicine, general practice'},
#  'matfet': {'matfet'},
#  'neuro-psychologist': {'neuro-psychologist'},
#  'oncology, internal medicine': {'endocrinology, internal medicine',
#   'oncology, internal medicine'},
#  'physical therapist - orthopedic': {'physical therapist - orthopedic'},
#  'thoracic and cardiovascular surgery': {'thoracic & cardiovascular surgery',
#   'thoracic and cardiovascular surgery'},
#  'uroonc': {'uroonc'},
#  'vasneu': {'vasneu'},
#  'community health center': {'community health center'},
#  'diagnostics (mobile)': {'diagnostics (mobile)', 'mobile diagnostic'},
#  'mastectomy supplies': {'mastectomy supplies'},
#  'medical supply company without orthotist and  pros': {'medical supply company without orthotist and  pros'},
#  'physical therapist - pediatrics': {'physical therapist - pediatrics'},
#  'prosthetic orthotic supplier': {'prosthetic orthotic supplier'},
#  'pt/ot/st': {'pt/ot/st'},
#  'restpy': {'restpy'},
#  'speech therapy': {'speech therapy'},
#  'hospit': {'hospit'},
#  'long term hospital care': {'long term care hospital',
#   'long term hospital care'},
#  'neuro psych md': {'neuro psych md'},
#  'surgery - cardiothoracic': {'cardiothoracic surge',
#   'cardiothoracic surgery',
#   'surgery (cardiothoracic)',
#   'surgery - cardiothoracic'},
#  'head/neck surgery': {'head/neck surgery'},
#  'ob/gyn maternal fetal medicine': {'ob/gyn maternal fetal medicine'},
#  'pediatric cardiology': {'pediatric cardiology',
#   'pediatric radiology',
#   'pediatrics - cardiology',
#   'pediatrics - radiology'},
#  'audiometry': {'audiometry'},
#  'chiropractor - general': {'chiropractor - general'},
#  'dietician - registered': {'dietician - registered', 'dietitian, registered'},
#  'nurse practitioner - obstetrics & gynecology': {'nurse practitioner - obstetrics & gynecology'},
#  'physical therapy center': {'physical therapy center'},
#  'physiological laboratory': {'physiological laboratory'},
#  'pods': {'pods'},
#  'rehabilitation': {'rehabilitation'},
#  'surgery orthopedic - sports medicine': {'orthopedic surgery -sports medicine',
#   'surgery orthopedic - sports medicine'},
#  'colon/rectal surgery': {'colon & rectal surgery',
#   'colon / rectal surgery',
#   'colon and rectal surgery',
#   'colon/rectal surgery',
#   'colorectal surgery',
#   'surgery - colon & rectal'},
#  'portable x ray': {'portable x ray'},
#  'pros': {'pros'},
#  'psyca': {'psyca'},
#  'cna': {'cna'},
#  'long term care hosp': {'long term care hosp'},
#  'midwiv': {'midwiv'},
#  'sucrit': {'sucrit'},
#  'ahftc': {'ahftc'},
#  'rn': {'rn'},
#  'surgo': {'surgo'},
#  'agencies': {'agencies'},
#  'dentist, md': {'dentist, md'},
#  'allergy': {'allergy'},
#  'cardmo': {'cardmo'},
#  'npahth': {'npahth'},
#  'orthopaedics & ortho surgery': {'orthopaedics & ortho surgery'},
#  'radiation therapy center': {'radiation therapy center'},
#  'reproductive endocrinology': {'reproductive endocrinology'},
#  'special(ty) hospital': {'special(ty) hospital'},
#  'dpur': {'dpur'},
#  'genetics': {'genetics'},
#  'headache pain management': {'headache pain management'},
#  'otolaryngology - plastic surgery within the head &': {'otolaryngology - plastic surgery within the head &',
#   'otolaryngology plastic surgery within the head & n'},
#  'pat': {'pat'},
#  'physicians assistant': {'physician assistant',
#   "physician's assistant",
#   'physicians assistant'},
#  'rural health center': {'rural health center'},
#  'internal medicine/geriatrics': {'internal medicine - geriatric',
#   'internal medicine/geriatrics'},
#  'licensed counselor/social wrk': {'licensed counselor/social wrk'},
#  'nppsym': {'nppsym'},
#  'addmed': {'addmed'},
#  'config - clia certification': {'config - clia certification'},
#  'multiple healing arts professional association': {'multiple healing arts professional association'},
#  'sphear': {'sphear'},
#  'state hospital': {'state hospital'},
#  'bh': {'bh'},
#  'gerpsy': {'gerpsy'},
#  'portable x-ray provider (mobile diagnostic)': {'portable x-ray provider (mobile diagnostic)'},
#  'prictr': {'prictr'},
#  'rhc': {'rhc'},
#  'pediatric anesthesiology': {'pediatric anesthesiology',
#   'pediatrics - anesthesiology'},
#  'hypba': {'hypba'},
#  'anatomic pathology': {'anatomic pathology'},
#  'dental surgeon': {'dental surgeon'},
#  'fempel': {'fempel'},
#  'midwife': {'mdwife', 'midwife'},
#  'neurp': {'neurp'},
#  'physician group (md)': {'physician group (md)'},
#  'care manager': {'care manager'},
#  'others/swingbed': {'others/swingbed'},
#  'tbicrs': {'tbicrs'},
#  'clneu': {'clneu'},
#  'internal medicine - hospice and palliative medicin': {'internal medicine - hospice and palliative medicin'},
#  'pathology - cytopathology': {'pathology - cytopathology'},
#  'psychiatry & neurology - geriatric psychiatry': {'psychiatry & neurology - geriatric psychiatry'},
#  'pathology - clinical pathology/laboratory medicine': {'pathology - clinical pathology/laboratory medicine'},
#  'carecn': {'carecn'},
#  'meddp': {'meddp'},
#  'pot': {'pot'},
#  'psychiatry & neurology - psychiatry': {'psychiatry & neurology - psychiatry'},
#  'transplant surgeon': {'transplant surgeon'},
#  'pharmacy with infusion therapy': {'pharmacy infusion therapy',
#   'pharmacy with infusion therapy'},
#  'hepatology': {'hematology', 'hepatology', 'pathology'},
#  'pall': {'pall'},
#  'pathology - blood banking & transfusion medicine': {'pathology - blood banking & transfusion medicine'},
#  'psych & neurology': {'neuropsychology', 'psych & neurology'},
#  'hearing instrument specialist': {'hearing instrument specialist'},
#  'oncs': {'oncs'},
#  'medical supply company with prosthetist': {'medical supply company with prosthetist'},
#  'skilled nursing unit': {'skilled nursing unit'},
#  'facial plastic surgery': {'facial plastic surgery'},
#  'gencou': {'gencou'},
#  'orthopedic surgery -sports medicine': {'orthopedic surgery -sports medicine',
#   'surgery orthopedic - sports medicine'},
#  'suorsp': {'suorsp'},
#  'clinical laboratory': {'clinical laboratory'},
#  'mh': {'mh'},
#  'pediatrics - emergency care': {'pediatrics - emergency care'},
#  'internal medicine - hepatology': {'internal medicine - hepatology',
#   'internal medicine - nephrology',
#   'internal medicine - rheumatology',
#   'rheumatology, internal medicine'},
#  'registered nurse (private nurse)': {'registered nurse (private nurse)'},
#  'trauma surgery': {'surgery - trauma', 'trauma surgery'},
#  'tvs': {'tvs'},
#  'hospice & palliative medicine': {'hospice & palliative medicine'},
#  'physician/internal medicine': {'physician/internal medicine',
#   'physician/nuclear medicine'},
#  'specialty pharmacies': {'specialty pharmacies'},
#  'accup': {'accup'},
#  'aprn': {'aprn', 'arnp'},
#  'clinical genetics': {'clinical genetics'},
#  'dermatology surgery': {'dermatology surgery'},
#  'massage therapist': {'massage therapist'},
#  'ambulance service provider': {'ambulance service provider'},
#  'certified nurse practitioner': {'certified nurse practitioner',
#   'pediatric nurse practitioner'},
#  'clinical cardiac electrophys': {'clinical cardiac electrophys'},
#  'dme & supplies': {'dme & supplies'},
#  'early childhood intervention': {'early childhood intervention'},
#  'emergency response systems': {'emergency response systems'},
#  'gym': {'gym'},
#  'skilled nursing home': {'skilled nursing home'},
#  'sleep disorder clinic': {'sleep disorder clinic'},
#  'surgery, general': {'general surgery',
#   'surgery - general',
#   'surgery, general'},
#  'unknown md': {'unknown md'},
#  'walk-in clinic': {'walk-in clinic'},
#  'wound care center': {'wound care center'},
#  'anesthetist, nurse': {'anesthetist, nurse', 'nurse anesthetist'},
#  'physician/anesthesiology': {'physician/anesthesiology'},
#  'physician/gastroenterology': {'physician/gastroenterology'},
#  'family practice nurse prac': {'family practice nurse prac'},
#  'pathology - anatomic - clinic': {'anatomic and clinical pathology',
#   'pathology - anatomic - clinic'},
#  'physician/diagnostic radiology': {'physician/diagnostic radiology'},
#  'physician/emergency medicine': {'physician/emergency medicine'},
#  'physician/family practice': {'physician/family practice'},
#  'anatomic path & clinical path': {'anatomic path & clinical path'},
#  'blood banking/transfusion med': {'blood banking/transfusion med'},
#  'cardiovascular disease': {'cardiovascular disease'},
#  'certified registered nurse anesthetist (crna)': {'certified registered nurse anesthetist',
#   'certified registered nurse anesthetist (crna)',
#   'nurse anesthetist - certified registered'},
#  'clinical pathology': {'clinical pathology', 'pathology - clinical'},
#  'family medicine': {'family medicine'},
#  'hematology / oncology': {'hematology / oncology',
#   'hematology/oncology',
#   'oncology & hematology'},
#  'hospital-general': {'hospital-general'},
#  'obstetrics / gynecology': {'gynecology - no obstetrics',
#   'obstetrics & gynecology',
#   'obstetrics / gynecology',
#   'obstetrics and gynecology'},
#  'physician/cardiovascular disease (cardiology)': {'physician/cardiovascular disease (cardiology)'},
#  'physician/neurology': {'physician/nephrology',
#   'physician/neurology',
#   'physician/urology'},
#  'physician/pathology': {'physician/ophthalmology', 'physician/pathology'},
#  'physician/pulmonary disease': {'physician/pulmonary disease'},
#  'unknown': {'unknown'},
#  'physician/interventional radiology': {'physician/interventional radiology'},
#  'surgery of the hand': {'surgery of the hand'},
#  'physician/allergy/ immunology': {'physician/allergy/ immunology'},
#  'physician/dermatology': {'physician/dermatology', 'physician/rheumatology'},
#  'physician/endocrinology': {'physician/endocrinology'},
#  'physician/general surgery': {'physician/general surgery'},
#  'physician/hematology-oncology': {'physician/hematology-oncology'},
#  'physician/otolaryngology': {'physician/otolaryngology'},
#  'physician/pain management': {'physician/pain management'},
#  'physician/sports medicine': {'physician/sports medicine'},
#  'psych': {'psych'},
#  'endocrinology, diab/metabolism': {'endocrinology, diab/metabolism'},
#  'imaging facility': {'imaging facility'},
#  'medical oncology': {'medical oncology'},
#  'nurse practitioner acute care': {'nurse practitioner - acute care',
#   'nurse practitioner acute care'},
#  'nurse practnr. adult health': {'nurse practnr. adult health'},
#  'orthopaedic sports medicine': {'orthopaedic sports medicine'},
#  'orthopaedic surgery': {'orthopaedic surgery',
#   'orthopedic surgery',
#   'surgery - orthopedic'},
#  'pain medicine': {'pain medicine'},
#  'pathem': {'pathem'},
#  'physical medicine and rehab': {'physical medicine & rehab',
#   'physical medicine and rehab'},
#  'surgery': {'surgery'},
#  'surgery, cardiovascular': {'cardiovascular surgery',
#   'surgery - cardiovascular',
#   'surgery, cardiovascular'},
#  'therapy center speech occupational and physical': {'therapy center speech occupational and physical'},
#  'vascular & interventional rad': {'vascular & interventional rad'},
#  'certified clinical nurse specialist': {'certified clinical nurse specialist'},
#  'hdm': {'hdm'},
#  'independent diagnostic testing facility (idtf)': {'independent diagnostic testing facility',
#   'independent diagnostic testing facility (idtf)'},
#  'orthotics & prosthetics': {'orthotics & prosthetics',
#   'orthotics/prosthetics',
#   'prosthetic & orthotics',
#   'prosthetics and orthotics'},
#  'other medical supply company': {'other medical supply company'},
#  'pers': {'pers'},
#  'physician/physical medicine and rehabilitation': {'physician/physical medicine and rehabilitation'},
#  'anast': {'anast'},
#  'geriatric medicine nurse prac': {'geriatric medicine nurse prac'},
#  'multi specialty group': {'multi specialty group'},
#  'otology / neurotology': {'otology / neurotology'},
#  'suplre': {'suplre'},
#  'physician/orthopedic surgery': {'physician/orthopedic surgery'},
#  'physician/nephrology': {'physician/nephrology', 'physician/neurology'},
#  'physician/urology': {'physician/neurology', 'physician/urology'},
#  'physician/vascular surgery': {'physician/vascular surgery'},
#  'diagnostic treatment center': {'diagnostic treatment center'},
#  'laryngology': {'laryngology'},
#  'psyarn': {'psyarn'},
#  'surgery, transplant': {'surgery, transplant', 'transplant surgery'},
#  'anesthesia/tee': {'anesthesia/tee'},
#  'physician/infectious disease': {'physician/infectious disease'},
#  'gynecology - no obstetrics': {'gynecology - no obstetrics',
#   'obstetrics & gynecology',
#   'obstetrics / gynecology',
#   'obstetrics and gynecology'},
#  'rehhos': {'rehhos'},
#  'physician/nuclear medicine': {'physician/internal medicine',
#   'physician/nuclear medicine'},
#  'physician/thoracic surgery': {'physician/thoracic surgery'},
#  'clinical nurse specialist': {'clinical nurse specialist',
#   'clinical nurse specialist - bh'},
#  'diagnostic cardiac monitoring': {'diagnostic cardiac monitoring'},
#  'pediatric nurse practitioner': {'certified nurse practitioner',
#   'pediatric nurse practitioner'},
#  'pedspo': {'pedspo'},
#  'radiology - mobile unit': {'radiology - mobile unit'},
#  'thoracic/cardiothoracic vascular surgery': {'thoracic/cardiothoracic vascular surgery'},
#  'immunology': {'immunology'},
#  'adolescent medicine': {'adolescent medicine'},
#  'hospice and palliative med': {'hospice and palliative med'},
#  'psychiatry neurology osteopath': {'psychiatry neurology osteopath'},
#  'traumatic surgery': {'traumatic surgery'},
#  'unclassified non-physician': {'unclassified non-physician'},
#  'psynur': {'psynur'},
#  'geri': {'geri'},
#  'physician/ophthalmology': {'physician/ophthalmology', 'physician/pathology'},
#  'colon & rectal surgery': {'colon & rectal surgery',
#   'colon / rectal surgery',
#   'colon and rectal surgery',
#   'colon/rectal surgery',
#   'colorectal surgery',
#   'surgery - colon & rectal'},
#  'psychiatry, neurology': {'psychiatry, neurology'},
#  'pulmed': {'pulmed'},
#  'outpatient mental health clinician group': {'outpatient mental health clinician group'},
#  'pediatrics neonatology': {'pediatrics neonatology'},
#  'phgpm': {'phgpm'},
#  'pediatric emergency medicine': {'pediatric emergency medicine'},
#  'pedort': {'pedort'},
#  'advanced heart failure and transplant cardiology': {'advanced heart failure and transplant cardiology'},
#  'nonn': {'nonn'},
#  'surgery, oncologic': {'surgery, oncologic'},
#  'psychologist - rehabilitation': {'psychologist - rehabilitation'},
#  'audio': {'audio'},
#  'gynecology nurse practitioner': {'gynecology nurse practitioner',
#   'nurse practitioner - gerontology'},
#  'npgyno': {'npgyno'},
#  'paotrh': {'paotrh'},
#  'paurlo': {'paurlo'},
#  'pediatric rheumatology': {'pediatric rheumatology',
#   'radiology - therapeutic',
#   'therapeutic radiology'},
#  'hha': {'hha'},
#  'pharmacy infusion therapy': {'pharmacy infusion therapy',
#   'pharmacy with infusion therapy'},
#  'acupuncturist': {'acupuncturist'},
#  'reg nurse first assistant': {'reg nurse first assistant'},
#  'hep': {'hep'},
#  'otofps': {'otofps'},
#  'physical therapist in private practice': {'physical therapist in private practice'},
#  'physician/medical oncology': {'physician/medical oncology'},
#  'occmed': {'occmed'},
#  'occupational medicine': {'occupational medicine'},
#  'ambulance - emergency land': {'ambulance - emergency land'},
#  'clinical nurse specialist - bh': {'clinical nurse specialist',
#   'clinical nurse specialist - bh'},
#  'genet': {'genet'},
#  'in home wellness assessme': {'in home wellness assessme'},
#  'msg': {'msg'},
#  'pednus': {'pednus'},
#  'neurdi': {'neurdi', 'under'},
#  'nursing home': {'nursing home'},
#  'radiology facility': {'radiology facility'},
#  'physician/neurosurgery': {'physician/neurosurgery'},
#  'physician/obstetrics & gynecology': {'physician/obstetrics & gynecology'},
#  'physician/rheumatology': {'physician/dermatology', 'physician/rheumatology'},
#  'cert clinic nurse': {'cert clinic nurse'},
#  'nutri': {'nutri'},
#  'orthotics/pros fitte': {'orthotics/pros fitte', 'orthotics/prosthetics'},
#  'pathology services': {'pathology services'},
#  'fipal': {'fipal'},
#  'sptsur': {'sptsur'},
#  'physician/general practice': {'physician/general practice'},
#  'acupu': {'acupu'},
#  'preventive medicine - addiction medicine': {'preventive medicine - addiction medicine'},
#  'mdwife': {'mdwife', 'midwife'},
#  'mass immunization biller': {'mass immunization biller'},
#  'reciprocity physician': {'reciprocity physician'},
#  'vascul': {'vascu', 'vascul'},
#  'telemedicine': {'telemedicine'},
#  'pxrays': {'pxrays'},
#  'addpsy': {'addpsy'},
#  'fpmrs': {'fpmrs'},
#  'surgery-ob/gyn': {'surgery-ob/gyn'},
#  'racute': {'racute'},
#  'blood bank transfu': {'blood bank transfu'},
#  'vascular neurology': {'vascular neurology'},
#  'nponc': {'nponc'},
#  'clinical social worker': {'clinical social work',
#   'clinical social worker',
#   'lic clinical social worker'},
#  'plastic surgery within head & neck': {'plastic surgery within head & neck'},
#  'psych unit': {'psych unit'},
#  'nurse practnr. women health': {'nurse practnr. women health'},
#  'pediatric orthopaedics': {'pediatric orthopaedics'},
#  'acute short term hospital': {'acute short term hospital'},
#  'ambulatory surgical facility': {'ambulatory surgical facility'},
#  'anesthesia': {'anesthesia'},
#  'critical care physician': {'critical care physician'},
#  'dentistry': {'dentistry'},
#  'dialysis/renal care-medicare': {'dialysis/renal care-medicare'},
#  'emergency physician': {'emergency physician'},
#  'health care professionals-other': {'health care professionals-other'},
#  'home health care agency': {'home health care agency'},
#  'hospital long term acute care': {'hospital long term acute care'},
#  'laboratory center': {'laboratory center'},
#  'mental behavior hlth': {'mental behavior hlth'},
#  'mental health provider': {'mental health provider'},
#  'not mapped': {'not mapped'},
#  'op mental hlth/substance abuse': {'op mental hlth/substance abuse'},
#  'phar': {'phar'},
#  'physical rehabilitation professiona': {'physical rehabilitation professiona'},
#  'physicial medicine': {'physicial medicine'},
#  'pulmonary/critical care': {'pulmonary/critical care'},
#  'radiology center': {'radiology center'},
#  'sleep diagnostic center': {'sleep diagnostic center'},
#  'peder': {'peder'},
#  'certified registered nurse first assistant': {'certified registered nurse first assistant'},
#  'educational': {'educational'},
#  'npurlo': {'npurlo'},
#  'barias': {'barias'},
#  'manipulative therapy': {'manipulative therapy'},
#  'mat/fetal': {'mat/fetal'},
#  'long term care facility': {'long term care facility'},
#  'clinic center': {'clinic center'},
#  'clinic or group practice': {'clinic or group practice'},
#  'interventional pain management': {'interventional pain management'},
#  'otology, laryngology, rhinology': {'otology, laryngology, rhinology',
#   'otology, laryngology, rhinology (ent)'},
#  'long term care hospital': {'long term care hospital',
#   'long term hospital care'},
#  'neonatology': {'neonatology'},
#  'osteopathic manipulative med': {'osteopathic manipulative med'},
#  'rehabilitation unit': {'rehabilitation unit'},
#  'phlebotomy': {'phlebotomy'},
#  'diet': {'diet'},
#  'otorhi': {'otorhi'},
#  'pediatric allergy': {'pediatric allergy'},
#  'ctc': {'ctc'},
#  'behavioral health facility': {'behavioral health facility'},
#  'lic clinical social worker': {'clinical social worker',
#   'lic clinical social worker',
#   'licensed clinical social worker'},
#  'behavioral health unit': {'behavioral health unit'},
#  'ltch': {'ltch'},
#  'hyper baric treatment': {'hyper baric treatment'},
#  'error': {'error'},
#  'npagrt': {'npagrt'}}

# %%
df['CLAIM_SPECIALTY_final'] = df['CLAIM_SPECIALTY_formatted']\
.apply(lambda x: list(paired[x])[0])

df['pairednum'] = df['CLAIM_SPECIALTY_formatted']\
.apply(lambda x: len(list(paired[x])))

# %%
print("Unique Claim Specialty: ", len(df['CLAIM_SPECIALTY_final'].unique()))
# Out:
# Unique Claim Specialty:  689

# %% [markdown]
# Since we need to manually check claims specialty groups we will focus only those which have the highest paid amount

# %%
maxamount = df.groupby(['CLAIM_SPECIALTY_final']).\
agg({'PAID_AMOUNT':'sum', 'pairednum': 'min'}).\
reset_index().\
sort_values(['PAID_AMOUNT'], ascending = False)

# %%
maxamount[0:20]
# Out:
#         CLAIM_SPECIALTY_final  PAID_AMOUNT  pairednum
# 244                       inp     41412982          1
# 228                  hospital     40080688          1
# 396                       out     14024841          1
# 58                 cardiology      7520528          2
# 208       hematology/oncology      5910652          3
# 245         internal medicine      4822104          1
# 285            medical doctor      4556985          1
# 603                       snf      4248390          1
# 18                  ambulance      2437935          1
# 173           family practice      2123451          1
# 552        radiation oncology      2051066          1
# 594  skilled nursing facility      2009817          1
# 375       orthopaedic surgery      1972445          3
# 37             anesthesiology      1874916          1
# 259  interventional radiology      1868204          2
# 216               home health      1850499          1
# 581   renal dialysis facility      1833364          1
# 181          gastroenterology      1742810          1
# 639          surgery, general      1655168          3
# 546        pulmonary diseases      1475881          2

# %% [markdown]
# ### Manually checked top 20 - mapping is right

# %% [markdown]
# ## As it comes from data description - we should have unique combinations of (Month, SERVICE_CATEGORY, CLAIM_SPECIALTY, Payer)

# %%
df.columns
# Out:
# Index(['MONTH', 'SERVICE_CATEGORY', 'CLAIM_SPECIALTY', 'PAYER', 'PAID_AMOUNT',
#        'CLAIM_SPECIALTY_formatted', 'CLAIM_SPECIALTY_final', 'pairednum'],
#       dtype='object')

# %%
np.max(df.groupby(['MONTH', 'SERVICE_CATEGORY', 'CLAIM_SPECIALTY', 'PAYER']).count().reset_index()['PAID_AMOUNT'])
# Out:
# 1

# %%
np.max(df.groupby(['MONTH', 'SERVICE_CATEGORY', 'CLAIM_SPECIALTY_formatted', 'PAYER']).count().reset_index()['PAID_AMOUNT'])
# Out:
# 2

# %% [markdown]
# We will deal with new aggregation logic on the analytics stage

# %% [markdown]
# # Found that we have 2 bagged months - 202006 is empty and 2019 has 13 month - I will drop 201900

# %%
df = df[(df.MONTH != 202007) & (df.MONTH != 201900)]

# %% [markdown]
# # Save results

# %%
df.to_csv('claims_sample_data_cleared.csv')
